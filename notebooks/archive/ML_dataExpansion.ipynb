# %%
import numpy as np
import pandas as pd

# %%
ML1_results = np.load("ML1_results.npy", allow_pickle=True)
dfP = pd.DataFrame(ML1_results, columns=['School Curriculum','University', 'Major', 'Probability'])

dfP["Probability"] = dfP["Probability"].astype(float)

dfR_menu = pd.read_excel('University Ranking by Major 2025.xlsx', sheet_name="Menu")
dfR_Arts = pd.read_excel('University Ranking by Major 2025.xlsx', sheet_name="Architecture")
dfR = pd.read_excel('University Ranking by Major 2025.xlsx', engine='openpyxl', sheet_name="Biological")

# %%
dfR.head(50)
# Out:
#        QS World University Rankings by Subject Unnamed: 1  \
# 0                          Biological Sciences        NaN
# 1                                          NaN        NaN
# 2                                          NaN        NaN
# 3                                          NaN        NaN
# 4                                          NaN        NaN
# 5                                          NaN        NaN
# 6                                          NaN        NaN
# 7                                          NaN        NaN
# 8   Top 700 Universities - Biological Sciences        NaN
# 9                                         2025       2024
# 10                                           1          1
# 11                                           2          2
# 12                                           3          3
# 13                                           4          4
# 14                                           5          5
# ...

# %% [markdown]
# ### Mapeo

# %% [markdown]
# ### Generar estudiantes

# %% [markdown]
# ### Asignar etiquetas

# %% [markdown]
# ### Mezclar con df original
